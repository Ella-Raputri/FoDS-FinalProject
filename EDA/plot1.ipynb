# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/merge.csv')
df
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#                                               location  linkedin skill  \
# ...

# %%
# All Tiobe Index Ratings

plt.figure(figsize = (6,4))
df[["tiobe index ratings"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nTiobe Index Ratings 2024", fontsize = 14)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount", fontsize = 12)
plt.show()

# %%
# All NonZero Tiobe Index Ratings

plt.figure(figsize = (6,4))
nonzero = df[df["tiobe index ratings"] > 0]
nonzero[["tiobe index ratings"]].boxplot()

plt.title("Boxplot for Each Programming Language's \nTiobe Index Ratings 2024 (Nonzero)", fontsize = 14)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Percentage", fontsize = 12)
plt.show()

# %%
# All Job Amounts
plt.figure(figsize = (6,4))
df[["job amount"]].boxplot()
plt.title("Boxplot for Each Programming Language's Job Amount", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount", fontsize = 12)
plt.show()

# %%
# All Average Salary
plt.figure(figsize = (6,4))
df[["average salary"]].boxplot()
plt.title("Boxplot for Each Programming Language's Average Salary", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Average Salary", fontsize = 12)
plt.show()

# %%
# All Linkedin Skills

plt.figure(figsize = (6,4))
df[["linkedin skill"]].boxplot()
plt.title("Boxplot for Each Programming Language's Linkedin Skill", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()

# %%
# All Nonzero Linkedin Skills

plt.figure(figsize = (6,4))
nonzero = df[df["linkedin skill"]>0]
nonzero[["linkedin skill"]].boxplot()

plt.title("Boxplot for Each Programming Language's \nLinkedin Skill (Nonzero)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()

# %%
# All Average Monthly Wiki Views
plt.figure(figsize = (6,4))

df[['wiki view Oct 2024']].boxplot()

plt.title("Boxplot for Each Programming Language's \nWikipedia Views (Monthly)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Average Views Monthly", fontsize = 12)
plt.show()

# %%
# All Nonzero Average Monthly Wiki Views
# We exclude the zero one because 0 means that there is no wikipedia page for that programming language
plt.figure(figsize = (6,4))

nonzero = df[df['wiki view Oct 2024']>0]
nonzero[['wiki view Oct 2024']].boxplot()

plt.title("Boxplot for Each Programming Language's \n Wikipedia Views (Monthly and Nonzero)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Average Views Monthly", fontsize = 12)
plt.show()

# %%
# All GitHub User Count

plt.figure(figsize = (6,4))
df[["github user count"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nGitHub User Count", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()

# %%
# All Nonzero GitHub User Count

plt.figure(figsize = (6,4))
nonzero = df[df["github user count"]>0]
nonzero[["github user count"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nGitHub User Count (Nonzero)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()

# %%
# All Average Search Count

plt.figure(figsize = (6,4))
df[["search count Oct 2024"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nTotal Search Count", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount", fontsize = 12)
plt.show()

# %%
# All Nonzero Average Search Count

plt.figure(figsize = (6,4))
nonzero = df[df["search count Oct 2024"]>0]
nonzero[["search count Oct 2024"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nTotal Search Count (Nonzero)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount", fontsize = 12)
plt.show()

# %%
# All Stack Overflow User Count

plt.figure(figsize = (6,4))
df[["stack_overflow_count_2024"]].boxplot()
plt.title("Boxplot for Each Programming Language's \nStack Overflow User Count", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()

# %%
# All Nonzero Stack Overflow User Count

plt.figure(figsize = (6,4))
nonzero = df[df['stack_overflow_count_2024']>0]
nonzero[["stack_overflow_count_2024"]].boxplot()

plt.title("Boxplot for Each Programming Language's \nStack Overflow User Count (Nonzero)", fontsize = 15)
plt.xlabel("Variable", fontsize = 12)
plt.ylabel("Amount of User", fontsize = 12)
plt.show()
