# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/merge.csv')
df
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#                                               location  linkedin skill  \
# ...

# %%
filtered_df = df[(df.select_dtypes(include=['float64', 'int64']) > 0).all(axis=1)]

numeric_columns = filtered_df.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(filtered_df[column], bins=10, kde=True, color='skyblue', edgecolor='black')

    plt.title(f"Histogram with Trend Line of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
for column in numeric_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(filtered_df[column], bins=10, kde=True, color='skyblue', edgecolor='black')
    plt.title(f"Histogram with Trend Line of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()
