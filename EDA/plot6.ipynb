# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/merge.csv')
df
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#                                               location  linkedin skill  \
# ...

# %%
#Heatmap
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Variables")
plt.show()

# %%
# exclude -1
columns_to_check = ['tiobe index ratings', 'job amount', 'average salary', 'linkedin skill', 
                    'wiki view Oct 2024', 'github user count', 'search count Oct 2024', 
                    'stack_overflow_count_2024']

df_filtered = df[~df[columns_to_check].isin([-1]).any(axis=1)]
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 152
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   programming language       30 non-null     object
#  1   tiobe index ratings        30 non-null     float64
#  2   job amount                 30 non-null     int64
#  3   average salary             30 non-null     float64
#  4   location                   30 non-null     object
#  5   linkedin skill             30 non-null     int64
#  6   github user count          30 non-null     int64
#  7   wiki view Oct 2024         30 non-null     float64
#  8   search count Oct 2024      30 non-null     int64
#  9   stack_overflow_count_2024  30 non-null     int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.6+ KB

# %%
correlation_matrix = df_filtered.select_dtypes(include=['float64', 'int64']).corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Variables (Excluding -1)")
plt.show()
