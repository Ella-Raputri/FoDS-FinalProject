# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../../data/merge.csv')
df['location_count'] = df['location'].apply(lambda x: len(eval(x)))
df.drop('location',axis=1, inplace=True)
df
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#      linkedin skill  github user count  wiki view Oct 2024  \
# ...

# %%
# standardize the data
scaler = StandardScaler()
df[['tiobe index ratings_T','job amount_T','average salary_T','linkedin skill_T',
    	'wiki view Oct 2024_T','github user count_T','search count Oct 2024_T',
        'stack_overflow_count_2024_T','location_count_T']] = scaler.fit_transform(df[['tiobe index ratings','job amount',
        'average salary','linkedin skill',
    	'wiki view Oct 2024','github user count','search count Oct 2024',
        'stack_overflow_count_2024','location_count']])

df
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#      linkedin skill  github user count  wiki view Oct 2024  \
# ...

# %%
df.to_csv('standardized_result.csv', index=False)

# %%
df1 = pd.read_csv('cluster_result.csv')
df1['dbscan_cluster'] = df1['dbscan_cluster'].replace({1: 0, 0: 1})
df1['birch_cluster'] = df1['birch_cluster'].replace({1: 0, 0: 1})
df1
# Out:
#     programming language  tiobe index ratings  job amount  average salary  \
# 0                   Java                10.51         728    6.153528e+06
# 1             JavaScript                 3.54        1111    6.168157e+06
# 2                   Dart                 0.56          32    6.250161e+06
# 3                Node.js                 0.00         450    5.596209e+06
# 4                    PHP                 1.21         505    5.762279e+06
# ..                   ...                  ...         ...             ...
# 170                   Dc                 0.00           1    5.592859e+06
# 171             VBScript                 0.33           2    3.327448e+06
# 172                CORAL                 0.00           1    3.244448e+06
# 173             UniVerse                 0.00           1    1.520833e+06
# 174                   C2                 0.00          38    1.560417e+06
#
#      linkedin skill  github user count  wiki view Oct 2024  \
# ...

# %%
df1['cluster_count'] = (
    (df1['kmeans_2'] == 0).astype(int) +
    (df1['agg_cluster'] == 0).astype(int) +
    (df1['dbscan_cluster'] == 0).astype(int) + 
    (df1['birch_cluster'] == 0).astype(int)
)
df1[df1['cluster_count'] >= 2]['programming language']
# Out:
# 0           Java
# 1     JavaScript
# 4            PHP
# 6          MySQL
# 8            SQL
# 9     PostgreSQL
# 14        Python
# 20             C
# 41           C++
# Name: programming language, dtype: object

# %%
print(df['programming language'])
# Out:
# 0            Java
# 1      JavaScript
# 2            Dart
# 3         Node.js
# 4             PHP
#           ...
# 170            Dc
# 171      VBScript
# 172         CORAL
# 173      UniVerse
# 174            C2
# Name: programming language, Length: 175, dtype: object
