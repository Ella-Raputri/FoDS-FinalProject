# %%
import pandas as pd
import numpy as np
import re
from sklearn.impute import SimpleImputer

# %%
def cleanSalary(txt):
    if isinstance(txt, str):
        numbers = re.findall(r'\d{1,3}(?:,\d{3})*', txt)
        if numbers:
            max_salary = int(numbers[-1].replace(',', ''))
            return max_salary
        else:
            num = re.findall(r'\d{1,3}(?:\.\d{3})*', txt)
            if num:
                max_salary = int(num[-1].replace('.', ''))
                return max_salary
        return None
    return txt

# %%
df = pd.DataFrame()

for i in range(1, 14):
    file_name = f'scrapping_result/jobdata{i}.csv'
    dfx = pd.read_csv(file_name) 
    dfx['Salary'] = dfx['Salary'].apply(cleanSalary) 

    num_cols = dfx.select_dtypes(include=['float64']).columns
    imp = SimpleImputer(strategy='mean')
    dfx[num_cols] = imp.fit_transform(dfx[num_cols])

    df = pd.concat([df, dfx], ignore_index=True, sort=False)  


for i in range(1, 14):
    file_name = f'scrapping_result/jobstreet{i}.csv'
    dfx = pd.read_csv(file_name) 
    dfx.drop('Date', axis=1, inplace=True)
    dfx['Salary'] = dfx['Salary'].apply(cleanSalary) 

    num_cols = dfx.select_dtypes(include=['float64']).columns
    imp = SimpleImputer(strategy='mean')
    dfx[num_cols] = imp.fit_transform(dfx[num_cols])

    df = pd.concat([df, dfx], ignore_index=True, sort=False)


df.rename(str.lower, axis='columns', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5138 entries, 0 to 5137
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job title        5137 non-null   object
#  1   company name     5127 non-null   object
#  2   location         5137 non-null   object
#  3   salary           5138 non-null   float64
#  4   job type         4176 non-null   object
#  5   job description  5136 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 241.0+ KB

# %%
df.drop_duplicates(inplace=True)
df = df.dropna(subset=['job title','company name', 'job description'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3307 entries, 0 to 5137
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job title        3307 non-null   object
#  1   company name     3307 non-null   object
#  2   location         3307 non-null   object
#  3   salary           3307 non-null   float64
#  4   job type         2866 non-null   object
#  5   job description  3307 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 180.9+ KB

# %%
def cleanTitle(txt):
    x = re.sub(r"\s*-\s*job post$", "", txt, flags=re.IGNORECASE).strip().lower()
    return x

df['job title'] = df['job title'].apply(cleanTitle)

df['job title']
# Out:
# 0                                    full stack developer
# 1                                    full stack developer
# 2                             full stack junior developer
# 3         senior full-stack developer (angular/expressjs)
# 4                             front-end (react) developer
#                               ...
# 5133                                 blockchain developer
# 5134                                 blockchain developer
# 5135                    integrator & operations (backend)
# 5136                                    symfony developer
# 5137    application support developer (for banking ind...
# Name: job title, Length: 3307, dtype: object

# %%
language_df = pd.read_csv('nama.csv')
languages = language_df['title'].tolist()
print(languages)
# Out:
# ['Java', 'JavaScript', 'JS', 'C', 'Python', 'Phyton', 'SQL', 'C++', 'PHP', 'Perl', 'MATLAB', 'Ruby', 'C#', 'MySQL', 'Fortran', 'R', 'Go', 'Scala', 'Swift', 'Ada', 'COBOL', 'Rust', 'PostgreSQL', 'Kotlin', 'Arduino', 'PowerShell', 'Pascal', 'Haskell', 'TypeScript', 'SAS', 'ARM', 'Lisp', 'Lua', 'Julia', 'Prolog', 'Node.js', 'Objective-C', 'Clojure', 'Scheme', 'Assembly', 'Erlang', 'Bash', 'Mathematica', 'Elixir', 'CUDA', 'Dart', 'Modula-2', 'Visual Basic', 'Tcl', 'ActionScript', 'VBA', 'BASIC', 'Delphi', 'Solidity', 'F#', 'Regular Expressions', 'OCaml', 'Eiffel', 'Crystal', 'Modula-3', 'Racket', 'Groovy', 'Common Lisp', 'Reason', 'Sage', 'Maple', 'CoffeeScript', 'APL', 'OpenCL', 'XQuery', 'GraphQL', 'SPSS', 'Scratch', 'Visual Basic .NET', 'PureBasic', 'Haxe', 'VBScript', 'Oberon', 'LabVIEW G', 'Applescript', 'Oz', 'Lasso', 'ECMAScript', 'Red', 'Simula', 'Idris', 'SQLite', 'AMPL', 'BCPL', 'PL/SQL', 'Dylan', 'REBOL', 'PureScript', 'FLUX', 'Fantom', 'Squirrel', 'EuLisp', 'Monkey', 'Limbo', 'Agda', 'BlitzBasic', 'GAME', 'Emacs Lisp', 'ColdFusion', 'AutoIt', 'Makefile', 'Vala', 'NewLisp', 'Nemerle', 'Zig', 'Jison', 'MoonScript', 'Terra', 'X10', 'Ballerina', 'Scilab', 'Flow', 'Turing', 'idyll', 'Mercury', 'QML', 'IDL', 'Frege', 'xBase', 'GNU Octave', 'Boo', 'Object Pascal', 'MicroPython', 'Hy', 'ALGOL 60', 'Arc', 'Zephir', 'SPARQL', 'Ceylon', 'Opa', 'SuperCollider', 'SystemVerilog', 'QBasic', 'SNOBOL', 'Cython', 'XPath', 'Inform', 'CLIPS', 'Pony', 'RobotFramework', 'PL/pgSQL', 'Factor', 'Stata', 'Multi-User Forth', 'Nextflow', 'Pike', 'grep', 'PL/I', 'Isabelle', 'NetLogo', 'API Blueprint', 'MiniD', 'Click', 'ATS', 'AutoLISP', 'S-algol', 'Csound', 'F*', 'AGC', 'FoxPRO', 'ClojureScript', 'Ioke', 'INTERCAL', 'Wren', 'Alloy', 'odin', 'AXIOM', 'LiveScript', 'CSP', 'Modelica', 'POV-Ray SDL', 'Clipper', 'YARA', 'Batchfile', 'MariaDB', 'GAMS', 'M4', 'Datalog', 'Objective-J', 'Dafny', 'C--', 'Wolfram', 'Oxygene', 'Gambas', 'Q', 'HyperTalk', 'SPARK', 'halide', 'TLA', 'Miranda', 'Speedie', 'Bourne shell', 'C3', 'Visual FoxPro', 'Seed7', 'PowerBuilder', 'Coconut', 'Simulink', 'Oberon-2', 'G-code', 'Genie', 'QuickBASIC', 'Maxima', 'AutoHotkey', 'Classroom Object Oriented Language', 'PL/0', 'GW-BASIC', 'SETL', 'LINQ', 'ECL', 'Falcon', 'SaltStack', 'ALGOL 68', 'XBase++', 'Netwide Assembler', 'Transact-SQL', 'CLU', 'Dc', 'COMTRAN', 'Scala.js', 'PRQL', 'HyperCard', 'Jython', 'Bluespec', 'Croc', 'True BASIC', 'WxBasic', 'UrWeb', 'GAP', 'Sather', 'Vim script', 'FreeBASIC', 'JScript', 'unison', 'Pig Latin', 'TXL', 'chrysaLisp', 'CIL', 'starlark', 'Nu', 'Multics', 'Malbolge', 'Tiny BASIC', 'Xtend', 'ALGOL W', 'DTrace', 'Ragel', 'AspectJ', 'Caml', 'Fortress', 'PARI/GP', 'Pure Data', 'muPad', 'HLSL', 'Unicon', 'RPL', 'Gosu', 'OpenVera', 'Fennel', 'JCL', 'RATFOR', 'GLSL', 'Curry', 'MusicXML', 'Slash', 'Enso', 'Luna', 'Golo', 'NSIS', 'Expect', 'janet', 'Ladder Logic', 'beef-lang', 'Inno Setup', 'Dogescript', 'PL/M', 'LilyPond', 'datascript', 'QB64', 'SWI Prolog', 'WDL', 'Korn shell', 'Imba', 'Koka', 'Altair BASIC', 'IGOR Pro', 'CWL', 'UNLAMBDA', 'gravity', 'Java EE version history', 'SourcePawn', 'OpenLisp', 'Blitz3D', "Ren'Py", 'Commodore BASIC', 'Taichi', 'PIR', 'LPC', 'Reia', 'carp', 'GAMS', 'Euphoria', 'Microsoft Small Basic', 'Guile', 'Qualcomm Hexagon', 'RoboMind', 'Jule', 'Aith', 'Dockerfile', 'CFML', 'KiXtart', 'NewtonScript', 'Information Presentation Facility', 'PIC microcontroller', 'LotusScript', 'DRAKON', 'Microsoft Macro Assembler', 'beads-lang', 'JADE', 'Pharo', 'Svelte', 'PROMETHEUS', 'Mirah', 'Ghostscript', 'Sqlalchemy', 'CPL', 'Modula', 'BlitzPlus', 'Bel', 'ACT-III', 'Papyrus', 'Clarion', 'VRML', 'progsbase', 'Spin', 'SQLPL', 'ThinBasic', 'ARexx', 'CLOS', 'PAWN', 'Alice', 'Uno', 'Futhark', 'ALGOL 58', 'JAI', 'Nial', 'S3', 'CodeQL', 'Yoix', 'mgmt', 'Simple Binary Encoding', 'Felix', 'MBASIC', 'FLOW-MATIC', 'Slope', 'NetLinx', 'Jakt', 'P4', 'Nushell', 'Curl', 'Visual Prolog', 'Aldor', 'Mathcad', 'Joy', 'QMake', 'ProvideX', 'XProc', 'Cobra', 'Cy ...

# %%
def extract_languages(job_description):
    found_languages = []
    for language in languages:
        if language == "C++":
            pattern = r'\bC\+\+(?!\w)'  # Match C++ only
        elif language == "R++":
            pattern = r'\bR\+\+(?!\w)'  # Match R++ only
        elif language == "D++":
            pattern = r'\bD\+\+(?!\w)'  # Match D++ only
        elif language == "Pro*C":
            pattern = r'\bPro\*C\b'  # Match Pro*C only
        elif language == "Low*":
            pattern = r'\bLow\*\b'  # Match Low* only
        elif language == "ASP.NET":
            pattern = r'\bASP[ .]?NET\b'  # Match ASP.NET or ASP .NET
        elif language == "Visual FoxPro":
            pattern = r'\bVisual\s?Fox\s?Pro\b'  
        elif language == "Node.js":
            pattern = r'\bNode[.\s]?js\b'  # Match "Node.js", "node js", "Nodejs"
        else:
            pattern = fr'\b{language}\b' if language.isalnum() else fr'\b{language}\B'
        
        if re.search(pattern, job_description, re.IGNORECASE):
            found_languages.append(language)
    return found_languages

df['programming language'] = df['job description'].apply(extract_languages)


csharp_jobs = df[df['programming language'].apply(lambda x: 'C#' in x)]
print("\nRows with C# found:")
print(csharp_jobs)
# Out:
# Rows with C# found:
#                                               job title  \
# 11                                 full stack developer
# 18    technical team lead, trilogy (remote) - $60,00...
# 34                                   software developer
# 37               it core banking (full stack developer)
# 45                        software developer / engineer
# ...                                                 ...
# 5103                     global software engineer (c++)
# 5118                                  software engineer
# 5119                                  software engineer
# 5124         fullstack .net developer - leasing company
# 5127                                     odoo developer
#
#                                 company name                    location  \
# 11                      Dnalytics Consulting                     Jakarta
# 18                                 Crossover                   Indonesia
# 34                 PT ALTERA CIPTA TEKNOLOGI                   Tangerang
# 37                PT Bank KEB Hana Indonesia                     Jakarta
# 45                       Pinnacle Investment                     Jakarta
# ...                                      ...                         ...
# 5103     PT Samsung SDS Global SCL Indonesia                     Jakarta
# 5118                                Snaphunt                     Jakarta
# 5119                             PLS Pte Ltd                     Jakarta
# 5124  PT. SIGMA GLOBAL TEKNOLOGI (SIGMATECH)                     Jakarta
# 5127             Permata Teknologi Solusindo  Tangerang District, Banten
#
#             salary       job type  \
# 11    1.100471e+07      Full-time
# 18    1.100471e+07      Full-time
# 34    7.000000e+06      Full-time
# 37    1.100471e+07            NaN
# 45    1.100471e+07            NaN
# ...            ...            ...
# 5103  3.410448e+06  Contract/Temp
# 5118  3.410448e+06      Full time
# 5119  3.410448e+06      Full time
# 5124  3.410448e+06  Contract/Temp
# 5127  3.410448e+06      Full time
#
#                                         job description  \
# 11    Seeking a versatile web developer proficient i...
# 18    Are you a talented software engineer who regul...
# 34    Qualifications:\n1. 3+ years of overall softwa...
# 37    Informasi Lowongan\nTipe Pekerjaan\n\nRemote/O...
# 45    Develop, improve, and maintain robust trading ...
# ...                                                 ...
# 5103  Position Summary\r\n1. Understand and implemen...
# 5118  The Offer\r\nGood Opportunity\r\nThe Job\r\nYo...
# 5119  PLS Pte Ltd is a dynamic company committed to ...
# 5124  Requirements :\r\n1. Able to work as team play...
# 5127  In general, candidate will develop function, f...
#
#                                    programming language
# 11    [JavaScript, JS, C, Python, SQL, PHP, C#, MySQ...
# 18    [JavaScript, C, Python, SQL, C#, TypeScript, B...
# 34                     [JavaScript, C, SQL, C#, F*, A+]
# 37    [Java, C, SQL, PHP, Ruby, C#, MySQL, F*, april...
# 45    [Java, JavaScript, C, Python, SQL, C++, PHP, P...
# ...                                                 ...
# 5103     [Java, C, Python, C#, Click, F*, Plus, P*, A+]
# 5118             [C, C#, F*, Plus, FOCUS, JS++, P*, A+]
# 5119             [C, C#, F*, Plus, FOCUS, JS++, P*, A+]
# 5124                     [C, C#, F*, .QL, JS++, P*, A+]
# 5127  [JavaScript, C, Python, SQL, C#, PostgreSQL, F...
#
# [249 rows x 7 columns]

# %%
csharp_jobs = df[df['programming language'].apply(lambda x: 'C#' in x)]
print(csharp_jobs)
# Out:
#                                               job title  \
# 11                                 full stack developer
# 18    technical team lead, trilogy (remote) - $60,00...
# 34                                   software developer
# 37               it core banking (full stack developer)
# 45                        software developer / engineer
# ...                                                 ...
# 3012                     global software engineer (c++)
# 3027                                  software engineer
# 3028                                  software engineer
# 3033         fullstack .net developer - leasing company
# 3036                                     odoo developer
#
#                                 company name                    location  \
# 11                      Dnalytics Consulting                     Jakarta
# 18                                 Crossover                   Indonesia
# 34                 PT ALTERA CIPTA TEKNOLOGI                   Tangerang
# 37                PT Bank KEB Hana Indonesia                     Jakarta
# 45                       Pinnacle Investment                     Jakarta
# ...                                      ...                         ...
# 3012     PT Samsung SDS Global SCL Indonesia                     Jakarta
# 3027                                Snaphunt                     Jakarta
# 3028                             PLS Pte Ltd                     Jakarta
# 3033  PT. SIGMA GLOBAL TEKNOLOGI (SIGMATECH)                     Jakarta
# 3036             Permata Teknologi Solusindo  Tangerang District, Banten
#
#             salary       job type  \
# 11    1.100471e+07      Full-time
# 18    1.100471e+07      Full-time
# 34    7.000000e+06      Full-time
# 37    1.100471e+07            NaN
# 45    1.100471e+07            NaN
# ...            ...            ...
# 3012  3.410448e+06  Contract/Temp
# 3027  3.410448e+06      Full time
# 3028  3.410448e+06      Full time
# 3033  3.410448e+06  Contract/Temp
# 3036  3.410448e+06      Full time
#
#                                         job description  \
# 11    Seeking a versatile web developer proficient i...
# 18    Are you a talented software engineer who regul...
# 34    Qualifications:\n1. 3+ years of overall softwa...
# 37    Informasi Lowongan\nTipe Pekerjaan\n\nRemote/O...
# 45    Develop, improve, and maintain robust trading ...
# ...                                                 ...
# 3012  Position Summary\r\n1. Understand and implemen...
# 3027  The Offer\r\nGood Opportunity\r\nThe Job\r\nYo...
# 3028  PLS Pte Ltd is a dynamic company committed to ...
# 3033  Requirements :\r\n1. Able to work as team play...
# 3036  In general, candidate will develop function, f...
#
#                                    programming language
# 11    [JavaScript, MySQL, ASP.NET, Node.js, C#, JS++...
# 18    [JavaScript, TypeScript, Visual Basic, C#, FOC...
# 34                             [JavaScript, C#, C, SQL]
# 37          [Java, MySQL, april, C#, C, SQL, Ruby, PHP]
# 45    [Java, JavaScript, Perl, C++, C#, C, SQL, Pyth...
# ...                                                 ...
# 3012                       [Java, C#, Click, C, Python]
# 3027                               [C#, FOCUS, JS++, C]
# 3028                               [C#, FOCUS, JS++, C]
# 3033                                 [C#, JS++, C, .QL]
# 3036       [JavaScript, C#, C, SQL, Python, PostgreSQL]
#
# [225 rows x 7 columns]

# %%
df = df[df['programming language'].str.len() > 0].reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2718 entries, 0 to 2717
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job title             2718 non-null   object
#  1   company name          2718 non-null   object
#  2   location              2718 non-null   object
#  3   salary                2718 non-null   float64
#  4   job type              2318 non-null   object
#  5   job description       2718 non-null   object
#  6   programming language  2718 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 148.8+ KB

# %%
def basic_combine(lang_list):
    return ['Visual Basic' if lang in ['BASIC Programming', 'BASIC'] else lang for lang in lang_list]

def js_typofix(lang_list):
    return ['JavaScript' if lang in ['JS'] else lang for lang in lang_list]

def python_typofix(lang_list):
    return ['Python' if lang in ['Phyton'] else lang for lang in lang_list]

def remove_duplicates(lang_list):
    return list(set(lang_list))

df['programming language'] = df['programming language'].apply(basic_combine)
df['programming language'] = df['programming language'].apply(js_typofix)
df['programming language'] = df['programming language'].apply(python_typofix)
df['programming language'] = df['programming language'].apply(remove_duplicates)

# %%
d = {}

def note_numlanguage(languages):
    for lang_list in languages:
        for lang in lang_list:  
            if lang in d:
                d[lang] += 1  
            else:
                d[lang] = 1  

note_numlanguage(df['programming language'])

print(len(d))
for key, value in d.items():
    print(f"{key}: {value}")
# Out:
# 178
# Java: 728
# JavaScript: 1111
# Dart: 32
# Node.js: 450
# PHP: 505
# Visual Basic: 234
# MySQL: 511
# TypeScript: 211
# SQL: 793
# PostgreSQL: 365
# Flow: 120
# CHAIN: 64
# Z++: 99
# FOCUS: 326
# Python: 675
# kernel: 1
# Address: 141
# ASP.NET: 84
# C#: 225
# JS++: 181
# C: 362
# GraphQL: 62
# Go: 211
# Ada: 71
# Ruby: 112
# MariaDB: 24
# Scheme: 6
# Expect: 33
# Copilot: 8
# Solidity: 4
# solid: 338
# pipelines: 244
# RAPID: 31
# NPL: 1
# april: 3
# flagship: 11
# Swift: 96
# Small: 72
# Kotlin: 117
# Simplicity: 5
# Perl: 18
# C++: 118
# Scratch: 25
# R: 148
# F: 14
# Rust: 27
# Groovy: 10
# Scala: 36
# Revolution: 61
# MATLAB: 17
# Apex: 11
# Click: 54
# Adept: 21
# .QL: 26
# dss: 2
# SPARK: 82
# Pure: 3
# GAP: 23
# Falcon: 2
# Alpha: 3
# Plot: 46
# Joy: 57
# CONVERT: 23
# Frank: 1
# P: 38
# lever: 1
# JADE: 5
# Blue: 3
# THINK C: 11
# Inform: 32
# NATURAL: 68
# Reason: 11
# ARM: 6
# SR: 6
# Crystal: 11
# PowerHouse: 11
# Conceptual: 22
# Factor: 10
# False: 2
# RPL: 4
# SQLite: 12
# fe: 7
# Chrome: 3
# Tao: 4
# Flavors: 4
# Cyber: 15
# Bash: 42
# DEMOS: 7
# Q: 4
# PROMETHEUS: 29
# Gist: 3
# PILOT: 6
# REDUCE: 28
# Monkey: 1
# Z: 1
# abs: 1
# FaCT: 5
# MACRO: 2
# FLUX: 4
# ECMAScript: 3
# Argus: 3
# Assembly: 6
# PowerShell: 21
# Visual FoxPro: 5
# FoxPRO: 6
# Delphi: 5
# SCM: 2
# Red: 14
# MetaL: 3
# SaltStack: 1
# bamboo: 13
# Mercury: 3
# UNITY: 12
# Arduino: 2
# SAS: 15
# SPSS: 22
# SIGNAL: 4
# Spatial: 15
# AL: 5
# jasper: 3
# PowerBuilder: 1
# SRL: 2
# Logos: 2
# Virgil: 1
# Dale: 1
# LUCID: 1
# CUDA: 2
# LINQ: 1
# JOVIAL: 2
# APL: 3
# BASIC A+: 6
# Cell: 2
# MIMIC: 4
# Charity: 2
# Meson: 1
# DYNAMO: 1
# Haskell: 3
# PLANNER: 2
# Gherkin: 3
# OBJ: 2
# frame: 4
# Tea: 1
# Sqlalchemy: 6
# Erlang: 14
# Sage: 5
# Lisp: 1
# Lua: 1
# F#: 1
# bloom: 3
# score: 4
# HL7: 4
# VBA: 9
# ActionScript: 3
# Elixir: 4
# MAPPER: 1
# Boo: 7
# Pan: 2
# l2: 13
# Augment: 2
# FP: 2
# fp: 2
# Vale: 2
# candor: 1
# Stata: 1
# Arc: 1
# DML: 8
# IPL: 1
# XL: 4
# Star: 3
# fox: 2
# LEAP: 7
# Dockerfile: 1
# Dc: 1
# VBScript: 2
# Coral: 1
# CORAL: 1
# UniVerse: 1
# C2: 38

# %%
remove_list = [
    'F*', 'P*', 'A+','T','S3','video','address','USD','Plus','never','Link','GAME','lain','Fun','small','click',
    'oil','ten','Nice'
]

def remove_unwanted_languages(lang_list):
    return [lang for lang in lang_list if lang not in remove_list]

df['programming language'] = df['programming language'].apply(remove_unwanted_languages)

# %%
df = df[df['salary'] > 0].reset_index(drop=True)
df.to_csv('job_cleaned.csv', index=False)

# %%
df.head()
# Out:
#                                          job title  \
# 0                             full stack developer
# 1                             full stack developer
# 2                      full stack junior developer
# 3  senior full-stack developer (angular/expressjs)
# 4                      front-end (react) developer
#
#                    company name location        salary   job type  \
# 0                       Edugate  Jakarta  7.000000e+06  Full-time
# 1  Techtiera Services Indonesia   Bekasi  8.000000e+06  Full-time
# 2  PT Smart Milenium Effisiensi    Depok  5.067381e+06  Full-time
# 3                       Worldly  Jakarta  1.100471e+07  Full-time
# 4                      Bibit.id  Jakarta  1.100471e+07  Full-time
#
#                                      job description  \
# 0  Software Developer with the following requirem...
# 1  As a Full-Stack Developer, you will be tasked ...
# 2  Kualifikasi\nLaki-laki\nUsia Max 30 Thn\nBelum...
# 3  Senior Full-Stack Developer (Angular/ExpressJS...
# 4  Company Description\n\nBibit.id is a platform ...
#
#                                 programming language
# 0             [Java, JavaScript, Dart, Node.js, PHP]
# 1                                       [JavaScript]
# 2  [Visual Basic, JavaScript, MySQL, TypeScript, ...
# 3  [Flow, JavaScript, MySQL, TypeScript, Node.js,...
# 4                                [FOCUS, JavaScript]
