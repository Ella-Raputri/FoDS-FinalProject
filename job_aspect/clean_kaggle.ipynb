# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pldb.csv')
df

# pd.reset_option('display.max_columns')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_19736\2921040564.py:1: DtypeWarning: Columns (15,16,17,25,30,38,41,44,46,47,48,49,50,51,52,53,56,59,60,61,63,69,71,72,73,75,76,78,79,80,81,82,83,84,85,87,89,91,92,93,94,95,96,97,98,99,100,101,103,104,110,111,112,113,114,115,116,117,119,121,122,123,126,128,129,130,131,132,133,134,135,137,138,142,143,144,145,146,147,148,150,151,156,157,158,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,183,184,185,186,187,188,189,190,191,192,194,195,196,197,198,200,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319
# ...

# %%
# df[df['title'] == 'Ladder Logic']
df = df[df['type'].isin(['queryLanguage', 'visual', 'assembly','contractLanguage','pl'])]
df
# Out:
#                           title  appeared           type  \
# 0                          Java      1995             pl
# 1                    JavaScript      1995             pl
# 2                             C      1972             pl
# 3                        Python      1991             pl
# 4                           SQL      1974  queryLanguage
# ...                         ...       ...            ...
# 4813         Very Tiny Language      1976             pl
# 4814                      wizml      1997             pl
# 4815  Wolontis-Bell Interpreter      1955             pl
# 4816                         xl      1977             pl
# 4817                        XQL      1999  queryLanguage
#
#                          pldbId  rank  languageRank  factCount  lastActivity  \
# 0                          java     0           0.0        920          2022
# 1                    javascript     1           1.0        818          2022
# ...

# %%
df = df[(df['type'] != 'contractLanguage') | ((df['type'] == 'contractLanguage') & (df['title'] == 'Solidity'))]
df = df[(df['type'] != 'visual') | ((df['type'] == 'visual') & (df['title'] == 'Scratch'))]

# df[(df['type']== 'contractLanguage')]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3513 entries, 0 to 4817
# Columns: 353 entries, title to features.hasMethodChaining
# dtypes: float64(49), int64(9), object(295)
# memory usage: 9.5+ MB

# %%
pd.set_option('display.max_rows', 3)

df['featureCount'] = 0
feature_columns = [col for col in df.columns if col.startswith('features.')]

for col in feature_columns:
    df['featureCount'] += df[col].notnull() & (df[col] != False)

df.drop(columns=feature_columns, inplace=True)
df
# Out:
#      title  appeared           type pldbId  rank  languageRank  factCount  \
# 0     Java      1995             pl   java     0           0.0        920
# ...    ...       ...            ...    ...   ...           ...        ...
# 4817   XQL      1999  queryLanguage    xql  4817        4074.0          8
#
#       lastActivity  exampleCount  bookCount  ...  discord  versions.2007  \
# 0             2022            20        401  ...      NaN            NaN
# ...            ...           ...        ...  ...      ...            ...
# 4817          1999             1          0  ...      NaN            NaN
#
#       versions.2023  versions.2015 versions.2019 versions.2013 ebook  \
# 0               NaN            NaN           NaN           NaN   NaN
# ...             ...            ...           ...           ...   ...
# 4817            NaN            NaN           NaN           NaN   NaN
#
#      extensionOf zulip featureCount
# 0            NaN   NaN           33
# ...

# %%
name = ['downloadPageUrl','assignmentToken','compilerExplorer','replit',
        'pypl','emailList','spec','eventsPageUrl','cheatSheetUrl','nativeLanguage',
        'esolang','screenshot','githubLanguage.wrap','versions.2022','gdbSupport',
        'announcementMethod','gitlabRepo','demoVideo','isPublicDomain','subsetOf',
        'firstAnnouncement','packageInstallCount','oldName','runsOnVm','gitRepo',
        'annualReportsUrl','sourcehutRepo','renamedTo','conference','packageAuthors',
        'successorOf','photo','includeToken','forkOf','inputLanguages','redditDiscussion',
        'usesSemanticVersioning','funFact','isDead','irc','discord',
        'ebook','extensionOf','zulip','documentation','indeedJobs','projectEuler','visualParadigm',	
        'linkedInSkill','languageServerProtocolProject','githubLanguage.filenames',
        'releaseNotesUrl','languageServerProtocolProject.writtenIn','faqPageUrl','tiobe.currentRank',
        'forLanguages',	'packageCount','supersetOf','indeedJobs.2017','influencedBy','githubLanguage.group',
        'webRepl', 'codeMirror', 'monaco', 'jupyterKernel', 'githubLanguage.interpreters',
        'quineRelay', 'compilesTo', 'ubuntuPackage', 'indeedJobs.2022', 'packageRepository', 
        'antlr', 'officialBlogUrl', 'wikipedia.fileExtensions', 'booleanTokens', 
        'domainName.awisRank.2017', 'helloWorldCollection', 'githubLanguage.aliases', 
        'tryItOnline', 'writtenIn', 'keywords', 'githubLanguage.codemirror_mode', 
        'fileExtensions', 'tiobe', 'related', 'multiLineCommentTokens', 'aka', 'twitter', 
        'githubLanguage.codemirror_mime_type', 'standsFor', 'githubBigQuery', 
        'stringToken', 'rosettaCode', 'printToken', 'lineCommentToken', 'domainName.awisRank.2022', 
        'leachim6.filepath', 'githubLanguage.type', 'githubLanguage.ace_mode', 
        'githubLanguage.fileExtensions', 'githubRepo', 'website', 'githubBigQuery.repos', 
        'wikipedia', 'originCommunity', 'centralPackageRepositoryCount', 'reference', 
        'wikipedia.summary', 'wikipedia.pageId', 'wikipedia.related', 'fileType', 
        'githubRepo.description', 'description', 'githubLanguage.tm_scope']

df.drop(columns=name, inplace=True)
# hilangin 114 columns

# %%
starter = ['linguistGrammarRepo','leachim6','pygmentsHighlighter','meetup','rijuRepl','versions']

for i in range(0, len(starter)):
    deleteit = [col for col in df.columns if col.startswith(starter[i])]
    df.drop(columns = deleteit, inplace = True)

df.info() #hilangin 25 cols
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3513 entries, 0 to 4817
# Data columns (total 50 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     3513 non-null   object
#  1   appeared                                  3513 non-null   int64
#  2   type                                      3513 non-null   object
#  3   pldbId                                    3513 non-null   object
#  4   rank                                      3513 non-null   int64
#  5   languageRank                              3513 non-null   float64
#  6   factCount                                 3513 non-null   int64
#  7   lastActivity                              3513 non-null   int64
#  8   exampleCount                              3513 non-null   int64
#  9   bookCount                                 3513 non-null   int64
# ...

# %%
pd.set_option("display.max_rows", 8)
df.drop(df[df['numberOfUsers']==0].index, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2153 entries, 0 to 3464
# Data columns (total 50 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     2153 non-null   object
#  1   appeared                                  2153 non-null   int64
#  2   type                                      2153 non-null   object
#  3   pldbId                                    2153 non-null   object
#  4   rank                                      2153 non-null   int64
#  5   languageRank                              2153 non-null   float64
#  6   factCount                                 2153 non-null   int64
#  7   lastActivity                              2153 non-null   int64
#  8   exampleCount                              2153 non-null   int64
#  9   bookCount                                 2153 non-null   int64
# ...

# %%
# Assuming df is your DataFrame
df.loc[:, df.select_dtypes(include=['float', 'int']).columns] = df.select_dtypes(include=['float', 'int']).fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2153 entries, 0 to 3464
# Data columns (total 50 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     2153 non-null   object
#  1   appeared                                  2153 non-null   int64
#  2   type                                      2153 non-null   object
#  3   pldbId                                    2153 non-null   object
#  4   rank                                      2153 non-null   int64
#  5   languageRank                              2153 non-null   float64
#  6   factCount                                 2153 non-null   int64
#  7   lastActivity                              2153 non-null   int64
#  8   exampleCount                              2153 non-null   int64
#  9   bookCount                                 2153 non-null   int64
# ...

# %%
df['creators'].fillna('unknown', inplace=True)
df['country'].fillna('unknown', inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_19736\160285649.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['creators'].fillna('unknown', inplace=True)
# C:\Users\asus\AppData\Local\Temp\ipykernel_19736\160285649.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
mean = df['numberOfUsers'].mean() 
std = df['numberOfUsers'].std() 
threshold = 3
# df
df1 = df[(df['numberOfUsers'] >= mean - threshold * std) & (df['numberOfUsers'] <= mean + threshold * std)]['numberOfUsers']
df1[0:20].hist()
# Out:
# <Axes: >

# %%
df4 = df['title']
df4.to_csv('nama.csv')
# Out:
# 0             Java
# 1       JavaScript
# 2                C
# 3           Python
#            ...
# 3461        shakti
# 3462          skew
# 3463           T3X
# 3464       tiddler
# Name: title, Length: 2153, dtype: object

# %%
df
# Out:
#            title  appeared type      pldbId  rank  languageRank  factCount  \
# 0           Java      1995   pl        java     0           0.0        920
# 1     JavaScript      1995   pl  javascript     1           1.0        818
# 2              C      1972   pl           c     2           2.0        426
# 3         Python      1991   pl      python     3           3.0        691
# ...          ...       ...  ...         ...   ...           ...        ...
# 3461      shakti      2019   pl      shakti  3461        2938.0         12
# 3462        skew      2015   pl        skew  3462        2939.0         12
# 3463         T3X      1995   pl         t3x  3463        2940.0         12
# 3464     tiddler      2004   pl     tiddler  3464        2941.0         12
#
#       lastActivity  exampleCount  bookCount  ...  \
# 0             2022            20        401  ...
# 1             2022            54        351  ...
# 2             2022            26         78  ...
# ...
