# %%
import pandas as pd
import re
import ast
from sklearn.impute import SimpleImputer

# %%
job_df = pd.read_csv('job_cleaned.csv')
job_df['programming language'] = job_df['programming language'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
job_df = job_df[job_df['programming language'].str.len() > 0].reset_index(drop=True)
job_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2718 entries, 0 to 2717
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job title             2718 non-null   object
#  1   company name          2718 non-null   object
#  2   location              2718 non-null   object
#  3   salary                2718 non-null   float64
#  4   job type              2318 non-null   object
#  5   job description       2718 non-null   object
#  6   programming language  2718 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 148.8+ KB

# %%
d = {}

def note_numlanguage(languages):
    for lang_list in languages:
        for lang in lang_list:  
            if lang in d:
                d[lang] += 1  
            else:
                d[lang] = 1  

note_numlanguage(job_df['programming language'])

language_df = pd.DataFrame(columns=['programming language', 'job amount'])
print(len(d))
for key, value in d.items():
    new_row ={'programming language':key, 'job amount':value}
    language_df = language_df._append(new_row, ignore_index=True)
    print(f"{key}: {value}")
# Out:
# 178
# Java: 728
# JavaScript: 1111
# Dart: 32
# Node.js: 450
# PHP: 505
# Visual Basic: 234
# MySQL: 511
# TypeScript: 211
# SQL: 793
# PostgreSQL: 365
# Flow: 120
# CHAIN: 64
# Z++: 99
# FOCUS: 326
# Python: 675
# kernel: 1
# Address: 141
# ASP.NET: 84
# C#: 225
# JS++: 181
# C: 362
# GraphQL: 62
# Go: 211
# Ada: 71
# Ruby: 112
# MariaDB: 24
# Scheme: 6
# Expect: 33
# Copilot: 8
# Solidity: 4
# solid: 338
# pipelines: 244
# RAPID: 31
# NPL: 1
# april: 3
# flagship: 11
# Swift: 96
# Small: 72
# Kotlin: 117
# Simplicity: 5
# Perl: 18
# C++: 118
# Scratch: 25
# R: 148
# F: 14
# Rust: 27
# Groovy: 10
# Scala: 36
# Revolution: 61
# MATLAB: 17
# Apex: 11
# Click: 54
# Adept: 21
# .QL: 26
# dss: 2
# SPARK: 82
# Pure: 3
# GAP: 23
# Falcon: 2
# Alpha: 3
# Plot: 46
# Joy: 57
# CONVERT: 23
# Frank: 1
# P: 38
# lever: 1
# JADE: 5
# Blue: 3
# THINK C: 11
# Inform: 32
# NATURAL: 68
# Reason: 11
# ARM: 6
# SR: 6
# Crystal: 11
# PowerHouse: 11
# Conceptual: 22
# Factor: 10
# False: 2
# RPL: 4
# SQLite: 12
# fe: 7
# Chrome: 3
# Tao: 4
# Flavors: 4
# Cyber: 15
# Bash: 42
# DEMOS: 7
# Q: 4
# PROMETHEUS: 29
# Gist: 3
# PILOT: 6
# REDUCE: 28
# Monkey: 1
# Z: 1
# abs: 1
# FaCT: 5
# MACRO: 2
# FLUX: 4
# ECMAScript: 3
# Argus: 3
# Assembly: 6
# PowerShell: 21
# Visual FoxPro: 5
# FoxPRO: 6
# Delphi: 5
# SCM: 2
# Red: 14
# MetaL: 3
# SaltStack: 1
# bamboo: 13
# Mercury: 3
# UNITY: 12
# Arduino: 2
# SAS: 15
# SPSS: 22
# SIGNAL: 4
# Spatial: 15
# AL: 5
# jasper: 3
# PowerBuilder: 1
# SRL: 2
# Logos: 2
# Virgil: 1
# Dale: 1
# LUCID: 1
# CUDA: 2
# LINQ: 1
# JOVIAL: 2
# APL: 3
# BASIC A+: 6
# Cell: 2
# MIMIC: 4
# Charity: 2
# Meson: 1
# DYNAMO: 1
# Haskell: 3
# PLANNER: 2
# Gherkin: 3
# OBJ: 2
# frame: 4
# Tea: 1
# Sqlalchemy: 6
# Erlang: 14
# Sage: 5
# Lisp: 1
# Lua: 1
# F#: 1
# bloom: 3
# score: 4
# HL7: 4
# VBA: 9
# ActionScript: 3
# Elixir: 4
# MAPPER: 1
# Boo: 7
# Pan: 2
# l2: 13
# Augment: 2
# FP: 2
# fp: 2
# Vale: 2
# candor: 1
# Stata: 1
# Arc: 1
# DML: 8
# IPL: 1
# XL: 4
# Star: 3
# fox: 2
# LEAP: 7
# Dockerfile: 1
# Dc: 1
# VBScript: 2
# Coral: 1
# CORAL: 1
# UniVerse: 1
# C2: 38

# %%
language_list = language_df['programming language'].to_list()
language_salary_dict={}
language_location_dict={}
language_jobtitle_dict= {}

for lang in language_list:
    language_salary_dict[lang] = 0
    language_location_dict[lang] = []
    language_jobtitle_dict[lang] =[]

print(language_salary_dict)
# Out:
# {'Java': 0, 'JavaScript': 0, 'Dart': 0, 'Node.js': 0, 'PHP': 0, 'Visual Basic': 0, 'MySQL': 0, 'TypeScript': 0, 'SQL': 0, 'PostgreSQL': 0, 'Flow': 0, 'CHAIN': 0, 'Z++': 0, 'FOCUS': 0, 'Python': 0, 'kernel': 0, 'Address': 0, 'ASP.NET': 0, 'C#': 0, 'JS++': 0, 'C': 0, 'GraphQL': 0, 'Go': 0, 'Ada': 0, 'Ruby': 0, 'MariaDB': 0, 'Scheme': 0, 'Expect': 0, 'Copilot': 0, 'Solidity': 0, 'solid': 0, 'pipelines': 0, 'RAPID': 0, 'NPL': 0, 'april': 0, 'flagship': 0, 'Swift': 0, 'Small': 0, 'Kotlin': 0, 'Simplicity': 0, 'Perl': 0, 'C++': 0, 'Scratch': 0, 'R': 0, 'F': 0, 'Rust': 0, 'Groovy': 0, 'Scala': 0, 'Revolution': 0, 'MATLAB': 0, 'Apex': 0, 'Click': 0, 'Adept': 0, '.QL': 0, 'dss': 0, 'SPARK': 0, 'Pure': 0, 'GAP': 0, 'Falcon': 0, 'Alpha': 0, 'Plot': 0, 'Joy': 0, 'CONVERT': 0, 'Frank': 0, 'P': 0, 'lever': 0, 'JADE': 0, 'Blue': 0, 'THINK C': 0, 'Inform': 0, 'NATURAL': 0, 'Reason': 0, 'ARM': 0, 'SR': 0, 'Crystal': 0, 'PowerHouse': 0, 'Conceptual': 0, 'Factor': 0, 'False': 0, 'RPL': 0, 'SQLite': 0, 'fe': 0, 'Chrome': 0, 'Tao': 0, 'Flavors': 0, 'Cyber': 0, 'Bash': 0, 'DEMOS': 0, 'Q': 0, 'PROMETHEUS': 0, 'Gist': 0, 'PILOT': 0, 'REDUCE': 0, 'Monkey': 0, 'Z': 0, 'abs': 0, 'FaCT': 0, 'MACRO': 0, 'FLUX': 0, 'ECMAScript': 0, 'Argus': 0, 'Assembly': 0, 'PowerShell': 0, 'Visual FoxPro': 0, 'FoxPRO': 0, 'Delphi': 0, 'SCM': 0, 'Red': 0, 'MetaL': 0, 'SaltStack': 0, 'bamboo': 0, 'Mercury': 0, 'UNITY': 0, 'Arduino': 0, 'SAS': 0, 'SPSS': 0, 'SIGNAL': 0, 'Spatial': 0, 'AL': 0, 'jasper': 0, 'PowerBuilder': 0, 'SRL': 0, 'Logos': 0, 'Virgil': 0, 'Dale': 0, 'LUCID': 0, 'CUDA': 0, 'LINQ': 0, 'JOVIAL': 0, 'APL': 0, 'BASIC A+': 0, 'Cell': 0, 'MIMIC': 0, 'Charity': 0, 'Meson': 0, 'DYNAMO': 0, 'Haskell': 0, 'PLANNER': 0, 'Gherkin': 0, 'OBJ': 0, 'frame': 0, 'Tea': 0, 'Sqlalchemy': 0, 'Erlang': 0, 'Sage': 0, 'Lisp': 0, 'Lua': 0, 'F#': 0, 'bloom': 0, 'score': 0, 'HL7': 0, 'VBA': 0, 'ActionScript': 0, 'Elixir': 0, 'MAPPER': 0, 'Boo': 0, 'Pan': 0, 'l2': 0, 'Augment': 0, 'FP': 0, 'fp': 0, 'Vale': 0, 'candor': 0, 'Stata': 0, 'Arc': 0, 'DML': 0, 'IPL': 0, 'XL': 0, 'Star': 0, 'fox': 0, 'LEAP': 0, 'Dockerfile': 0, 'Dc': 0, 'VBScript': 0, 'Coral': 0, 'CORAL': 0, 'UniVerse': 0, 'C2': 0}

# %%
for _, row in job_df.iterrows():
    salary = row['salary']
    for lang in row['programming language']:
        language_salary_dict[lang] += salary

print(language_salary_dict)
# Out:
# {'Java': 4479768447.639802, 'JavaScript': 6852822430.894201, 'Dart': 200005138.40966603, 'Node.js': 2518294059.5166173, 'PHP': 2909950931.938514, 'Visual Basic': 1671768775.090993, 'MySQL': 2699152586.2269125, 'TypeScript': 1395920198.2517376, 'SQL': 5360096604.482176, 'PostgreSQL': 1839993798.0923576, 'Flow': 1114883780.38426, 'CHAIN': 972304055.6073251, 'Z++': 1172856090.8839326, 'FOCUS': 2690734522.305558, 'Python': 4272074951.70023, 'kernel': 34507957.0, 'Address': 888272557.5543638, 'ASP.NET': 479763949.8744648, 'C#': 1413156668.8828928, 'JS++': 1013739970.8601706, 'C': 2146290239.1312919, 'GraphQL': 356615000.12044597, 'Go': 1655744374.0390837, 'Ada': 546793184.6739922, 'Ruby': 823410051.0168891, 'MariaDB': 123791140.91538097, 'Scheme': 71066848.04069766, 'Expect': 591377169.8926609, 'Copilot': 83329155.05711356, 'Solidity': 38084271.47797595, 'solid': 2157237398.4837484, 'pipelines': 1356734670.2622058, 'RAPID': 170448582.83980486, 'NPL': 11004708.625, 'april': 14125541.958333334, 'flagship': 68237628.49458727, 'Swift': 658268220.3392805, 'Small': 936837102.2134728, 'Kotlin': 713819916.3668859, 'Simplicity': 54280090.6870155, 'Perl': 128279688.27705848, 'C++': 696663945.7004008, 'Scratch': 170483560.27078247, 'R': 1201097176.1737666, 'F': 211619622.7827866, 'Rust': 240062315.9950275, 'Groovy': 100628505.86055171, 'Scala': 218515337.87962815, 'Revolution': 186333278.82163242, 'MATLAB': 98003496.32715702, 'Apex': 85976819.32937995, 'Click': 450960908.0479953, 'Adept': 161677620.31184542, '.QL': 123937294.80649368, 'dss': 16597567.71590909, 'SPARK': 321126485.25828433, 'Pure': 32642399.65600775, 'GAP': 637811596.1703974, 'Falcon': 22573333.333333336, 'Alpha': 25124180.790960453, 'Plot': 424815662.7272725, 'Joy': 384542994.9419241, 'CONVERT': 236025554.2723329, 'Frank': 9373333.333333334, 'P': 465339170.12107843, 'lever': 9373333.333333334, 'JADE': 38729645.02626928, 'Blue': 257641544.78787875, 'THINK C': 63166424.54781042, 'Inform': 268001580.03519067, 'NATURAL': 613096519.0696859, 'Reason': 222323927.66025597, 'ARM': 27800714.242424242, 'SR': 40006199.244723864, 'Crystal': 56260795.87001711, 'PowerHouse': 70537714.71428573, 'Conceptual': 137818545.38386795, 'Factor': 70268076.5904218, 'False': 10894166.666666668, 'RPL': 30746666.666666668, 'SQLite': 60398001.604811564, 'fe': 28314417.659244526, 'Chrome': 31011024.364341088, 'Tao': 30670847.457627118, 'Flavors': 18595995.426523298, 'Cyber': 72779248.1530277, 'Bash': 272635370.5184465, 'DEMOS': 58385051.51515152, 'Q': 55015662.72727273, 'PROMETHEUS': 135059016.64486605, 'Gist': 12573333.333333334, 'PILOT': 64959265.51726568, 'REDUCE': 151068207.38070416, 'Monkey': 9373333.333333334, 'Z': 9373333.333333334, 'abs': 9373333.333333334, 'FaCT': 148892630.0916138, 'MACRO': 136134105.72727272, 'FLUX': 44005464.235308826, 'ECMAScript': 39528715.39534883, 'Argus': 30966666.66666667, 'Assembly': 56253183.97164733, 'PowerShell': 116595730.81942748, 'Visual FoxPro': 24580850.29796423, 'FoxPRO': 27825298.44931558, 'Delphi': 25440450.720934127, 'SCM': 18380952.38095238, 'Red': 134406648.6456257, 'MetaL': 20369174.880382776, 'SaltStack': 14000000.0, 'bamboo': 54017318.48534178, 'Mercury': 38528715.39534883, 'UNITY': 73093542.64567873, 'Arduino': 7778662.5, 'SAS': 46607141.5365745, 'SPSS': 45098026.31578947, 'SIGNAL': 11897149.122807018, 'Spatial': 47060503.54585255, 'AL': 25112354.27810855, 'jasper': 35264357.697674416, 'PowerBuilder': 11000000.0, 'SRL': 23264357.697674416, 'Logos': 13626000.0, 'Virgil': 11000000.0, 'Dale': 11000000.0, 'LUCID': 11000000.0, 'CUDA': 30000000.0, 'LINQ': 12264357.697674418, 'JOVIAL': 24528715.395348836, 'APL': 18059653.30665289, 'BASIC A+': 21058652.003894515, 'Cell': 14815205.155301537, 'MIMIC': 21600759.8442873, 'Charity': 13040673.487148102, 'Meson': 12264357.697674418, 'DYNAMO': 12264357.697674418, 'Haskell': 27079562.852975953, 'PLANNER': 24528715.395348836, 'Gherkin': 18225653.03589855, 'OBJ': 24528715.395348836, 'frame': 21115208.862208445, 'Tea': 3122 ...

# %%
amount_list = language_df['job amount'].to_list()

i=0
for key,val in language_salary_dict.items():
    language_salary_dict[key] = val/amount_list[i]
    i+=1

print(language_salary_dict)
# Out:
# {'Java': 6153528.08741731, 'JavaScript': 6168157.003505131, 'Dart': 6250160.5753020635, 'Node.js': 5596209.021148038, 'PHP': 5762279.073145573, 'Visual Basic': 7144311.004662363, 'MySQL': 5282098.994573214, 'TypeScript': 6615735.536738093, 'SQL': 6759264.31838862, 'PostgreSQL': 5041078.898883171, 'Flow': 9290698.169868832, 'CHAIN': 15192250.868864454, 'Z++': 11847031.221049825, 'FOCUS': 8253786.878237909, 'Python': 6328999.928444785, 'kernel': 34507957.0, 'Address': 6299805.372725985, 'ASP.NET': 5711475.593743629, 'C#': 6280696.3061461905, 'JS++': 5600773.319669451, 'C': 5928978.561136166, 'GraphQL': 5751854.840652354, 'Go': 7847129.7347823875, 'Ada': 7701312.4601970725, 'Ruby': 7351875.455507939, 'MariaDB': 5157964.20480754, 'Scheme': 11844474.673449611, 'Expect': 17920520.2997776, 'Copilot': 10416144.382139195, 'Solidity': 9521067.869493987, 'solid': 6382359.167111682, 'pipelines': 5560387.992877893, 'RAPID': 5498341.381929189, 'NPL': 11004708.625, 'april': 4708513.986111111, 'flagship': 6203420.772235206, 'Swift': 6856960.628534172, 'Small': 13011626.419631567, 'Kotlin': 6101024.9262127, 'Simplicity': 10856018.1374031, 'Perl': 7126649.348725472, 'C++': 5903931.743223736, 'Scratch': 6819342.410831299, 'R': 8115521.460633558, 'F': 15115687.341627615, 'Rust': 8891196.888704723, 'Groovy': 10062850.58605517, 'Scala': 6069870.496656338, 'Revolution': 3054643.915108728, 'MATLAB': 5764911.548656295, 'Apex': 7816074.484489086, 'Click': 8351127.926814728, 'Adept': 7698934.300564067, '.QL': 4766819.031018988, 'dss': 8298783.857954545, 'SPARK': 3916176.6494912724, 'Pure': 10880799.885335917, 'GAP': 27730938.96393032, 'Falcon': 11286666.666666668, 'Alpha': 8374726.930320151, 'Plot': 9235123.102766793, 'Joy': 6746368.332314458, 'CONVERT': 10261980.620536214, 'Frank': 9373333.333333334, 'P': 12245767.634765223, 'lever': 9373333.333333334, 'JADE': 7745929.005253856, 'Blue': 85880514.92929292, 'THINK C': 5742402.231619129, 'Inform': 8375049.3760997085, 'NATURAL': 9016125.280436559, 'Reason': 20211266.15093236, 'ARM': 4633452.373737373, 'SR': 6667699.874120644, 'Crystal': 5114617.806365192, 'PowerHouse': 6412519.519480521, 'Conceptual': 6264479.335630361, 'Factor': 7026807.65904218, 'False': 5447083.333333334, 'RPL': 7686666.666666667, 'SQLite': 5033166.800400964, 'fe': 4044916.8084635036, 'Chrome': 10337008.121447029, 'Tao': 7667711.864406779, 'Flavors': 4648998.8566308245, 'Cyber': 4851949.876868513, 'Bash': 6491318.345677298, 'DEMOS': 8340721.645021646, 'Q': 13753915.681818182, 'PROMETHEUS': 4657207.470512622, 'Gist': 4191111.1111111115, 'PILOT': 10826544.252877614, 'REDUCE': 5395293.120739435, 'Monkey': 9373333.333333334, 'Z': 9373333.333333334, 'abs': 9373333.333333334, 'FaCT': 29778526.01832276, 'MACRO': 68067052.86363636, 'FLUX': 11001366.058827206, 'ECMAScript': 13176238.465116277, 'Argus': 10322222.222222224, 'Assembly': 9375530.661941221, 'PowerShell': 5552177.658067975, 'Visual FoxPro': 4916170.059592846, 'FoxPRO': 4637549.741552597, 'Delphi': 5088090.1441868255, 'SCM': 9190476.19047619, 'Red': 9600474.90325898, 'MetaL': 6789724.960127592, 'SaltStack': 14000000.0, 'bamboo': 4155178.345026291, 'Mercury': 12842905.131782943, 'UNITY': 6091128.553806561, 'Arduino': 3889331.25, 'SAS': 3107142.7691049664, 'SPSS': 2049910.2870813394, 'SIGNAL': 2974287.2807017546, 'Spatial': 3137366.9030568367, 'AL': 5022470.8556217095, 'jasper': 11754785.899224805, 'PowerBuilder': 11000000.0, 'SRL': 11632178.848837208, 'Logos': 6813000.0, 'Virgil': 11000000.0, 'Dale': 11000000.0, 'LUCID': 11000000.0, 'CUDA': 15000000.0, 'LINQ': 12264357.697674418, 'JOVIAL': 12264357.697674418, 'APL': 6019884.435550963, 'BASIC A+': 3509775.333982419, 'Cell': 7407602.577650769, 'MIMIC': 5400189.961071825, 'Charity': 6520336.743574051, 'Meson': 12264357.697674418, 'DYNAMO': 12264357.697674418, 'Haskell': 9026520.950991984, 'PLANNER': 12264357.697674418, 'Gherkin': 6075217.678632851, 'OBJ': 12264357.697674418, 'frame': 5278802.215552111, 'Tea': 31222900.0, 'Sqlalchemy': 3709 ...

# %%
language_salary_df = pd.DataFrame(list(language_salary_dict.items()), columns=['programming language', 'average salary'])
language_df = pd.merge(language_df, language_salary_df, on='programming language')

language_df.head()
# Out:
#   programming language job amount  average salary
# 0                 Java        728    6.153528e+06
# 1           JavaScript       1111    6.168157e+06
# 2                 Dart         32    6.250161e+06
# 3              Node.js        450    5.596209e+06
# 4                  PHP        505    5.762279e+06

# %%
for _, row in job_df.iterrows():
    location = row['location']
    for lang in row['programming language']:
        cleaned_text = re.sub(r'\b\w+(?:[\s-]\w+)*,\s*', '', location)
        if(cleaned_text!='Indonesia'): 
            if('Yogyakarta' in cleaned_text): cleaned_text='Yogyakarta'
            language_location_dict[lang].append(cleaned_text)
        else:
            match = re.search(r'^\s*(\w+(?:[\s-]\w+)*)\s*,', location)
            if match: language_location_dict[lang].append(match.group(1))
            else: continue


print(language_location_dict)
# Out:
# {'Java': ['Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jember', 'Jakarta', 'Jakarta', 'Jakarta', 'Badung', 'Medan', 'Jakarta', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'East Java', 'East Java', 'Surabaya', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Kuta', 'Yogyakarta', 'Tangerang', 'Bandung', 'Jakarta', 'Jakarta', 'Yogyakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Semarang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Garut', 'Jakarta', 'Semarang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Semarang', 'Semarang', 'Semarang', 'Semarang', 'Semarang', 'Semarang', 'Semarang', 'Semarang', 'Bandar Lampung', 'Jakarta', 'Semarang', 'Makassar', 'Semarang', 'Jakarta', 'Semarang', 'Bandar Lampung', 'Makassar', 'Surabaya', 'Bandar Lampung', 'Jakarta', 'Jakarta', 'Bandar Lampung', 'Jakarta', 'Jakarta', 'Central Java', 'Palembang', 'Jakarta', 'Jakarta', 'Makassar', 'Bandar Lampung', 'Makassar', 'Makassar', 'Bandar Lampung', 'Makassar', 'Bandar Lampung', 'Makassar', 'Surabaya', 'Jakarta', 'Garut', 'Palembang', 'Palembang', 'Bandar Lampung', 'Makassar', 'Surabaya', 'Surabaya', 'Bandar Lampung', 'Garut', 'Jakarta', 'Bandar Lampung', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Karawang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Semarang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Jakarta', 'Bali', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Semarang', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Central Java', 'Jakarta', 'Jakarta', 'Bandung', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Tangerang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Yogyakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Central Java', 'Semarang', 'Jakarta', 'Jakarta', 'Denpasar', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Central Java', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Bandung', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Banten', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Semarang', 'Jakarta', 'Surabaya', 'Bandung', 'Tangerang', 'Jakarta', 'Jakarta', 'Semarang', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'South Sumatra', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'West Java', 'Central Java', 'Jakarta', 'Jakarta', 'Banten', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'East Java', 'North Sumatra', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'West Java', 'West Java', 'West Java', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'West Java', 'Banten', 'Jakarta', 'Jakarta', 'North Sumatra', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Banten', 'Jakarta', 'Yogyakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'West Java', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'East Java', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Banten', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta', 'Jakarta',  ...

# %%
# for key, lis in language_location_dict.items():
#     lis2 = list(set(lis))
#     language_location_dict[key] = lis2

# print(language_location_dict)

# %%
language_location_df = pd.DataFrame(list(language_location_dict.items()), columns=['programming language', 'location'])
language_df = pd.merge(language_df, language_location_df, on='programming language')

language_df.head()
# Out:
#   programming language job amount  average salary  \
# 0                 Java        728    6.153528e+06
# 1           JavaScript       1111    6.168157e+06
# 2                 Dart         32    6.250161e+06
# 3              Node.js        450    5.596209e+06
# 4                  PHP        505    5.762279e+06
#
#                                             location
# 0  [Jakarta, Jakarta, Jakarta, Jakarta, Jember, J...
# 1  [Jakarta, Bekasi, Depok, Jakarta, Jakarta, Jak...
# 2  [Jakarta, Jakarta, East Java, East Java, Jakar...
# 3  [Jakarta, Jakarta, Jakarta, Jakarta, Jakarta, ...
# 4  [Jakarta, Depok, Jakarta, Jakarta, Jakarta, Yo...

# %%
for _, row in job_df.iterrows():
    job_title = row['job title']
    for lang in row['programming language']:
        language_jobtitle_dict[lang].append(job_title)


len(language_jobtitle_dict['Python'])
# Out:
# 675

# %%
language_jobtitle_df = pd.DataFrame(list(language_jobtitle_dict.items()), columns=['programming language', 'job title'])
language_df = pd.merge(language_df, language_jobtitle_df, on='programming language')

language_df.head()
# Out:
#   programming language job amount  average salary  \
# 0                 Java        728    6.153528e+06
# 1           JavaScript       1111    6.168157e+06
# 2                 Dart         32    6.250161e+06
# 3              Node.js        450    5.596209e+06
# 4                  PHP        505    5.762279e+06
#
#                                             location  \
# 0  [Jakarta, Jakarta, Jakarta, Jakarta, Jember, J...
# 1  [Jakarta, Bekasi, Depok, Jakarta, Jakarta, Jak...
# 2  [Jakarta, Jakarta, East Java, East Java, Jakar...
# 3  [Jakarta, Jakarta, Jakarta, Jakarta, Jakarta, ...
# 4  [Jakarta, Depok, Jakarta, Jakarta, Jakarta, Yo...
#
#                                            job title
# 0  [full stack developer, full stack developer, f...
# 1  [full stack developer, full stack developer, f...
# 2  [full stack developer, software engineer for t...
# 3  [full stack developer, senior full-stack devel...
# 4  [full stack developer, full stack junior devel...

# %%
language_df.to_csv('language_list_2.csv', index=False)

# %%
language_df.describe()
# Out:
#        average salary
# count    1.780000e+02
# mean     8.211338e+06
# std      8.959404e+06
# min      7.763158e+05
# 25%      4.634477e+06
# 50%      6.290251e+06
# 75%      9.374981e+06
# max      8.588051e+07
