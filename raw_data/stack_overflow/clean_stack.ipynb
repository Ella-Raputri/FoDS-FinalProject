# %%
import numpy as np
import pandas as pd
import glob
import os

# %%
columns_2021_to_2024 = [
    'languagehaveworkedwith', 'languagewanttoworkwith', 
    'databasehaveworkedwith', 'databasewanttoworkwith', 
    'webframehaveworkedwith', 'webframewanttoworkwith'
]

columns_2019_to_2020 = [
    'languageworkedwith', 'languagedesirenextyear', 
    'databaseworkedwith', 'databasedesirenextyear',  
    'webframeworkedwith', 'webframedesirenextyear'
]

column_mapping_2019_to_2020 = {
    'languageworkedwith': 'languagehaveworkedwith',
    'languagedesirenextyear': 'languagewanttoworkwith',
    'databaseworkedwith': 'databasehaveworkedwith',
    'databasedesirenextyear': 'databasewanttoworkwith',
    'webframeworkedwith': 'webframehaveworkedwith',
    'webframedesirenextyear': 'webframewanttoworkwith'
}

columns_2018 = [
    'languageworkedwith', 'languagedesirenextyear', 
    'databaseworkedwith', 'databasedesirenextyear',  
    'frameworkworkedwith', 'frameworkdesirenextyear'
]

column_mapping_2018 = {
    'languageworkedwith': 'languagehaveworkedwith',
    'languagedesirenextyear': 'languagewanttoworkwith',
    'databaseworkedwith': 'databasehaveworkedwith',
    'databasedesirenextyear': 'databasewanttoworkwith',
    'frameworkworkedwith': 'webframehaveworkedwith',
    'frameworkdesirenextyear': 'webframewanttoworkwith'
}

columns_2017 = [
    'haveworkedlanguage', 'wantworklanguage',
    'haveworkeddatabase', 'wantworkdatabase',
    'haveworkedframework', 'wantworkframework'
]

column_mapping_2017 = {
    'haveworkedlanguage': 'languagehaveworkedwith',
    'wantworklanguage': 'languagewanttoworkwith',
    'haveworkeddatabase': 'databasehaveworkedwith',
    'wantworkdatabase': 'databasewanttoworkwith',
    'haveworkedframework': 'webframehaveworkedwith',
    'wantworkframework': 'webframewanttoworkwith'
}

# %%
csv_files = glob.glob('data/*.csv')  
dataframes = []

# %%
for file in csv_files:
    year = int(os.path.basename(file).split('.')[0])

    df = pd.read_csv(file)
    df = df[df['Country'] == 'Indonesia']
    df.columns = df.columns.str.lower()

    if year >= 2021:
        df = df[columns_2021_to_2024]

    elif 2018 <= year <= 2020:
        if year == 2018:
            df = df[columns_2018].rename(columns=column_mapping_2018)
        else:
            df = df[columns_2019_to_2020].rename(columns=column_mapping_2019_to_2020)

    elif year == 2017:
        df = df[columns_2017].rename(columns=column_mapping_2017)

    dataframes.append(df)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25032\653827417.py:4: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df
# Out:
#                                  languagehaveworkedwith  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                   C#; JavaScript; SQL
# 3            C++; C#; JavaScript; PHP; SQL; VB.NET; VBA
# 4                                                Python
# ...                                                 ...
# 3936                        HTML/CSS;JavaScript;PHP;SQL
# 3937                                                NaN
# 3938                                                Ada
# 3939  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 3940            HTML/CSS;Java;JavaScript;PHP;Python;SQL
#
#                                  languagewanttoworkwith  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                            C#; Elixir
# 3     C; C++; C#; Java; JavaScript; PHP; Python; Rub...
# 4                                    JavaScript; Python
# ...                                                 ...
# 3936                     Go;HTML/CSS;PHP;Python;SQL;Zig
# 3937                                                NaN
# 3938                                                NaN
# 3939                    Elixir;Go;JavaScript;TypeScript
# 3940                   HTML/CSS;Java;JavaScript;PHP;SQL
#
#                                databasehaveworkedwith  \
# 0                                                 NaN
# 1                                                 NaN
# 2               SQL Server; MySQL; PostgreSQL; SQLite
# 3               SQL Server; MySQL; PostgreSQL; Oracle
# 4                                                 NaN
# ...                                               ...
# 3936                                      MySQL;Redis
# 3937                                              NaN
# 3938                                              NaN
# 3939                         MariaDB;PostgreSQL;Redis
# 3940  H2;Microsoft SQL Server;MySQL;PostgreSQL;SQLite
#
#                               databasewanttoworkwith  \
# 0                                                NaN
# 1                                                NaN
# 2                                         PostgreSQL
# 3     MongoDB; SQL Server; MySQL; PostgreSQL; SQLite
# 4                            Cassandra; Redis; MySQL
# ...                                              ...
# 3936     Clickhouse;Elasticsearch;MySQL;Redis;SQLite
# 3937                                             NaN
# 3938                                             NaN
# 3939                       Cockroachdb;Elasticsearch
# 3940                                           MySQL
#
#                                 webframehaveworkedwith  \
# 0                                                  NaN
# 1                                                  NaN
# 2                 AngularJS; Node.js; React; .NET Core
# 3                           AngularJS; Hadoop; Node.js
# 4                                                  NaN
# ...                                                ...
# 3936  CodeIgniter;Htmx;jQuery;Laravel;Vue.js;WordPress
# 3937                                               NaN
# 3938                                               NaN
# 3939    CodeIgniter;jQuery;Node.js;React;Svelte;Vue.js
# 3940                          jQuery;React;Spring Boot
#
#                                  webframewanttoworkwith
# 0                                                   NaN
# 1                                                   NaN
# 2                                             .NET Core
# 3     AngularJS; Node.js; React; Cordova; Xamarin; ....
# 4                                         Hadoop; Spark
# ...                                                 ...
# 3936   Astro;Htmx;jQuery;Laravel;Solid.js;Svelte;Vue.js
# 3937                                                NaN
# 3938                                                NaN
# 3939                  CodeIgniter;Phoenix;Svelte;Vue.js
# 3940            jQuery;Next.js;React;Spring Boot;Svelte
#
# [3941 rows x 6 columns]

# %%
combined_df.dropna(subset=columns_2021_to_2024, how='all',inplace=True)
combined_df
# Out:
#                                  languagehaveworkedwith  \
# 2                                   C#; JavaScript; SQL
# 3            C++; C#; JavaScript; PHP; SQL; VB.NET; VBA
# 4                                                Python
# 5                                  C; C++; C#; PHP; SQL
# 6                                  JavaScript; PHP; SQL
# ...                                                 ...
# 3935                                 Ada;JavaScript;PHP
# 3936                        HTML/CSS;JavaScript;PHP;SQL
# 3938                                                Ada
# 3939  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 3940            HTML/CSS;Java;JavaScript;PHP;Python;SQL
#
#                                  languagewanttoworkwith  \
# 2                                            C#; Elixir
# 3     C; C++; C#; Java; JavaScript; PHP; Python; Rub...
# 4                                    JavaScript; Python
# 5                                            JavaScript
# 6                                  JavaScript; PHP; SQL
# ...                                                 ...
# 3935                Go;JavaScript;PHP;Python;TypeScript
# 3936                     Go;HTML/CSS;PHP;Python;SQL;Zig
# 3938                                                NaN
# 3939                    Elixir;Go;JavaScript;TypeScript
# 3940                   HTML/CSS;Java;JavaScript;PHP;SQL
#
#                                databasehaveworkedwith  \
# 2               SQL Server; MySQL; PostgreSQL; SQLite
# 3               SQL Server; MySQL; PostgreSQL; Oracle
# 4                                                 NaN
# 5                                               MySQL
# 6                                               MySQL
# ...                                               ...
# 3935                        Elasticsearch;MySQL;Redis
# 3936                                      MySQL;Redis
# 3938                                              NaN
# 3939                         MariaDB;PostgreSQL;Redis
# 3940  H2;Microsoft SQL Server;MySQL;PostgreSQL;SQLite
#
#                                  databasewanttoworkwith  \
# 2                                            PostgreSQL
# 3        MongoDB; SQL Server; MySQL; PostgreSQL; SQLite
# 4                               Cassandra; Redis; MySQL
# 5                                             Cassandra
# 6                                          Redis; MySQL
# ...                                                 ...
# 3935  Elasticsearch;Firebase Realtime Database;Mongo...
# 3936        Clickhouse;Elasticsearch;MySQL;Redis;SQLite
# 3938                                                NaN
# 3939                          Cockroachdb;Elasticsearch
# 3940                                              MySQL
#
#                                 webframehaveworkedwith  \
# 2                 AngularJS; Node.js; React; .NET Core
# 3                           AngularJS; Hadoop; Node.js
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ...                                                ...
# 3935                                               NaN
# 3936  CodeIgniter;Htmx;jQuery;Laravel;Vue.js;WordPress
# 3938                                               NaN
# 3939    CodeIgniter;jQuery;Node.js;React;Svelte;Vue.js
# 3940                          jQuery;React;Spring Boot
#
#                                  webframewanttoworkwith
# 2                                             .NET Core
# 3     AngularJS; Node.js; React; Cordova; Xamarin; ....
# 4                                         Hadoop; Spark
# 5                                               Node.js
# 6                                        Node.js; React
# ...                                                 ...
# 3935                                                NaN
# 3936   Astro;Htmx;jQuery;Laravel;Solid.js;Svelte;Vue.js
# 3938                                                NaN
# 3939                  CodeIgniter;Phoenix;Svelte;Vue.js
# 3940            jQuery;Next.js;React;Spring Boot;Svelte
#
# [3508 rows x 6 columns]

# %%
combined_df.to_csv('indonesian_stack_overflow.csv', index=False)
